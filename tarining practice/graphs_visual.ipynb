# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv("car_dataset_cleaned.csv")

# %%
plt.bar(x=data["engine-size"],height=10,width=0.1)
# Out:
# <BarContainer object of 205 artists>
