# %%
import pandas as pd

# %%
data = {
    'Name': ['priya','nishaya','karan'],
    'Skills': ['Machine Learning,Data Science','Maths,Computer','English,Hindi'],
    'Experience': [3,5,10]}
print(len(data['Name']),len(data['Skills']),len(data['Experience']))
# Out:
# 3 3 3

# %%
df = pd.DataFrame(data)
df['Python_Proficient'] = df['Skills'].apply(lambda x: 'Python' in x)
print(df[df['Python_Proficient']])
# Out:
# Empty DataFrame
# Columns: [Name, Skills, Experience, Python_Proficient]
# Index: []
